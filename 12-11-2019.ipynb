# %% [markdown]
# ### Data cleaning
# * Importing the data set(CSV)
#
# * Observe the data set
#     * Identify the rows/col and their relation
#     * Identify the index col (Primary key column)
#     * Check if there are any duplicate columns
#     * which rows are to be skipped
#
# * Assign the index column(to avoid creation of new index col)
# * Skip the irrelevant rows(to avoid display of index row)
# * drop duplicate/irrelevant coloumns

# %%
import pandas as pd

df = pd.read_csv('olympics.csv', index_col=0, skiprows=1)

for col in df.columns:
    if col[:2]=='01':
        df.rename(columns={col:'Gold'+col[4:]}, inplace=True)
    if col[:2]=='02':
        df.rename(columns={col:'Silver'+col[4:]}, inplace=True)
    if col[:2]=='03':
        df.rename(columns={col:'Bronze'+col[4:]}, inplace=True)
    if col[:1]=='№':
        df.rename(columns={col:'#'+col[1:]}, inplace=True)

names_ids = df.index.str.split('\s\(') # split the index by '('

df.index = names_ids.str[0] # the [0] element is the country name (new index) 
df['ID'] = names_ids.str[1].str[:3] # the [1] element is the abbreviation or ID (take first 3 characters from that)

df = df.drop('Totals')
df.head()
# Out:
#              # Summer  Gold  Silver  Bronze  Total  # Winter  Gold.1  \
# Afghanistan        13     0       0       2      2         0       0
# Algeria            12     5       2       8     15         3       0
# Argentina          23    18      24      28     70        18       0
# Armenia             5     1       2       9     12         6       0
# Australasia         2     3       4       5     12         0       0
#
#              Silver.1  Bronze.1  Total.1  # Games  Gold.2  Silver.2  Bronze.2  \
# Afghanistan         0         0        0       13       0         0         2
# Algeria             0         0        0       15       5         2         8
# Argentina           0         0        0       41      18        24        28
# Armenia             0         0        0       11       1         2         9
# Australasia         0         0        0        2       3         4         5
#
#              Combined total   ID
# Afghanistan               2  AFG
# ...

# %% [markdown]
# ### Data Retrieval
#
# * Index Column----df.index
# * Column names----df.column
# * for a particular col----df["ksnka"]
# * for a particular row----df.head(1) or df.loc[row label name] or df.iloc[relevant positon num]

# %%
df
# Out:
#                                               № Summer  01 !  02 !  03 !  \
# Afghanistan (AFG)                                   13     0     0     2
# Algeria (ALG)                                       12     5     2     8
# Argentina (ARG)                                     23    18    24    28
# Armenia (ARM)                                        5     1     2     9
# Australasia (ANZ) [ANZ]                              2     3     4     5
# Australia (AUS) [AUS] [Z]                           25   139   152   177
# Austria (AUT)                                       26    18    33    35
# Azerbaijan (AZE)                                     5     6     5    15
# Bahamas (BAH)                                       15     5     2     5
# Bahrain (BRN)                                        8     0     0     1
# Barbados (BAR) [BAR]                                11     0     0     1
# Belarus (BLR)                                        5    12    24    39
# ...

# %%
df.index #Returns the Index col
df['Total'] #returns the total col
df.head(1)
# Out:
# 18
